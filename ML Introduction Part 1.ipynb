# %% [markdown]
# # This is a title
#
#
# This is text inside a markdown cell.
#
# *This is italic*
#
# **This is bold**
#
# [Markdown (formatting language) cheat sheet](https://github.com/adam-p/markdown-here/wiki/Markdown-Cheatsheet)

# %%
x = 1
y = 2
z = x + y
print('z =', z)

# %% [markdown]
# It allows inline charts as well:

# %%
import matplotlib.pyplot as plt
plt.plot([1, 2, 3, 4], [10, 2, 4, 10]);

# %%
x = 8
x

y = 2
